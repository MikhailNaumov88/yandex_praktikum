# %%
import pandas as pd

# %%
clients = pd.read_csv('clients.csv')
purchases = pd.read_csv('purchases.csv')
# Out:
# /tmp/ipykernel_7381/1139393976.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   purchases = pd.read_csv('purchases.csv')

# %%
clients
# Out:
#        Unnamed: 0 Дата добавления    Тип карты  \
# 0               0      2022-10-22  Стандартная
# 1               1      2022-10-22  Стандартная
# 2               2      2022-10-22  Стандартная
# 3               3      2022-10-22  Стандартная
# 4               4      2022-10-22  Стандартная
# ...           ...             ...          ...
# 20999       20999      2020-04-02  Стандартная
# 21000       21000      2020-03-27  Стандартная
# 21001       21001      2020-03-27  Стандартная
# 21002       21002      2020-03-27  Стандартная
# 21003       21003      2020-03-27  Стандартная
#
#                             Номер карты                       Моб.телефон  \
# 0      3c69db03e1f1ea1996a5ebf241467308  5c13f30c21d9cef89ec9408c049497a7
# 1      21ab2f983ac7ef581f6c0cd4a9f058a7  babb008e0127d702f62789baf388dbd6
# 2      7f768393a171d695439368439a812234  f8b8aec2bee7469bbc46943fb484c303
# 3      0ec4ddbd5aaa6a49722a5cf3003f3d39  8da4709238ea00c4bf84418353041eb2
# ...
